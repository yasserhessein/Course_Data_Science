# %% [markdown]
# ### Data repredentation by function matplotlib

# %%
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3,4],[5,6,7,8])

# %%
plt.plot([1,2,3,4],[5,6,2,8])

# %%
my_array1 = [4,1,6]

# %%
my_array2 = [1,20,3]

# %%
plt.plot(my_array1,my_array2)

# %%
plt.plot(my_array1,my_array2)
plt.title("Tow arrays")
plt.ylabel("Yasir")
plt.xlabel("Hussein")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
my_array3 = [11,20,33,55,87,7]
plt.plot(my_array3)
plt.title("my_array3")
plt.ylabel("Ammar")
plt.xlabel("Yasir")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
my_array4 = [1,2,4,5,6,7]
my_array5 = [8,7,13,50,81,7]
plt.plot(my_array4,my_array5)
plt.title("my_array4 & 5")
plt.ylabel("Ammar")
plt.xlabel("Yasir")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
my_array4 = [1,2,4,5,6,7]
my_array5 = [11,12,7,8,6,17]
plt.plot(my_array4,my_array5,"bo")
plt.title("my_array4 & 5")
plt.ylabel("Ammar")
plt.xlabel("Yasir")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
my_array4 = [1,2,4,5,6,7]
my_array5 = [11,12,7,8,6,17]
plt.plot(my_array4,my_array5,"^g:")
plt.title("my_array4 & 5")
plt.ylabel("Ammar")
plt.xlabel("Yasir")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
employee_name= ["yasir " , "hussein",   "shakir",   "naje"]
employee_salary= [3000,4300,5890,2000]

plt.figure(figsize=(35,4))

plt.subplot(151)
plt.bar(employee_name,employee_salary)


plt.subplot(152)
plt.plot(employee_name,employee_salary)



plt.subplot(153)
plt.scatter(employee_name,employee_salary)


plt.subplot(154)
plt.plot(employee_name,employee_salary,"^g:")

plt.title("Employee Info")
plt.ylabel("Y Salary")
plt.xlabel("X Name")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 2, 100)

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots()  # Create a figure and an axes.
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['path.simplify_threshold'] = 1.0

# Setup, and create the data to plot
y = np.random.rand(100000)
y[50000:] *= 2
y[np.geomspace(10, 50000, 400).astype(int)] = -1
mpl.rcParams['path.simplify'] = True

mpl.rcParams['agg.path.chunksize'] = 0
plt.plot(y)
plt.show()

mpl.rcParams['agg.path.chunksize'] = 10000
plt.plot(y)
plt.show()

# %%
import matplotlib.pyplot as plt


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.60       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

dt = 0.01
t = np.arange(0, 30, dt)
nse1 = np.random.randn(len(t))                 # white noise 1
nse2 = np.random.randn(len(t))                 # white noise 2

# Two signals with a coherent part at 10Hz and a random part
s1 = np.sin(2 * np.pi * 10 * t) + nse1
s2 = np.sin(2 * np.pi * 10 * t) + nse2

fig, axs = plt.subplots(2, 1)
axs[0].plot(t, s1, t, s2)
axs[0].set_xlim(0, 2)
axs[0].set_xlabel('time')
axs[0].set_ylabel('s1 and s2')
axs[0].grid(True)

cxy, f = axs[1].cohere(s1, s2, 256, 1. / dt)
axs[1].set_ylabel('coherence')

fig.tight_layout()
plt.show()

# %%
import numpy as np
np.random.seed(19680801)
import matplotlib.pyplot as plt


fig, ax = plt.subplots()
for color in ['tab:blue', 'tab:orange', 'tab:green']:
    n = 750
    x, y = np.random.rand(2, n)
    scale = 200.0 * np.random.rand(n)
    ax.scatter(x, y, c=color, s=scale, label=color,
               alpha=0.3, edgecolors='none')

ax.legend()
ax.grid(True)

plt.show()

# %% [markdown]
# # Good luck
